# %%
#import pysal as ps
import pysal as ps
#reload(pb)

# %%
municps = ps.open('./municipios.dbf')

# %%
len(municps)
# Out:
# 81

# %%
municps.to_df()
# Out:
#    STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID           NAME LSAD  \
# 0       72      073  01804517  0500000US72073  72073         Jayuya   13
# 1       72      119  01804540  0500000US72119  72119     Río Grande   13
# 2       72      015  01804487  0500000US72015  72015         Arroyo   13
# 3       72      019  01804489  0500000US72019  72019   Barranquitas   13
# 4       72      071  01804516  0500000US72071  72071        Isabela   13
# 5       72      021  01804490  0500000US72021  72021        Bayamón   13
# 6       72      091  01804526  0500000US72091  72091         Manatí   13
# 7       72      025  01804492  0500000US72025  72025         Caguas   13
# 8       72      127  01804544  0500000US72127  72127       San Juan   13
# 9       72      107  01804534  0500000US72107  72107       Orocovis   13
# 10      72      125  01804543  0500000US72125  72125     San Germán   13
# 11      72      003  01804481  0500000US72003  72003         Aguada   13
# ...

# %%
municps.to_df().iloc[[1,5,34]]
# Out:
#    STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID        NAME LSAD  \
# 1       72      119  01804540  0500000US72119  72119  Río Grande   13
# 5       72      021  01804490  0500000US72021  72021     Bayamón   13
# 34      72      097  01804529  0500000US72097  72097    Mayagüez   13
#
#         ALAND     AWATER                                           geometry
# 1   157013546   74871267  <pysal.cg.shapes.Polygon object at 0x7f3871e94...
# 5   114800037     493681  <pysal.cg.shapes.Polygon object at 0x7f3871e94...
# 34  201100448  508775673  <pysal.cg.shapes.Polygon object at 0x7f3871e9f...

# %%
out = ps.open('test.dbf', 'w', encoding='utf8')

# %%
out.header = municps.header
out.field_spec = municps.field_spec

# %%
out.write(municps.read_record(1))
out.write(municps.read_record(5))
out.write(municps.read_record(34))
# Out:
# <type 'unicode'>
# 72
# <type 'unicode'>
# 119
# <type 'unicode'>
# 01804540
# <type 'unicode'>
# 0500000US72119
# <type 'unicode'>
# 72119
# <type 'unicode'>
# Río Grande
# <type 'unicode'>
# 13
# <type 'unicode'>
# 72
# <type 'unicode'>
# 021
# <type 'unicode'>
# 01804490
# <type 'unicode'>
# 0500000US72021
# <type 'unicode'>
# 72021
# <type 'unicode'>
# Bayamón
# <type 'unicode'>
# 13
# <type 'unicode'>
# 72
# <type 'unicode'>
# 097
# <type 'unicode'>
# 01804529
# <type 'unicode'>
# 0500000US72097
# <type 'unicode'>
# 72097
# <type 'unicode'>
# Mayagüez
# <type 'unicode'>
# 13

# %%
out.close()

# %%
ps.open('./test.dbf', 'r', encoding='utf8').to_df()
# Out:
# pysal/core/Tables.py:217: UserWarning: Encountered the following error in attempting to read the shapefile ./test.shp. Proceeding with read, but the error will be reproduced below:
#  [Errno 2] No such file or directory: './test.shp'
#   ' {}'.format(self.dataPath[:-3]+'shp', e))
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID        NAME LSAD  \
# 0      72      119  01804540  0500000US72119  72119  Río Grande   13
# 1      72      021  01804490  0500000US72021  72021     Bayamón   13
# 2      72      097  01804529  0500000US72097  72097    Mayagüez   13
#
#        ALAND     AWATER
# 0  157013546   74871267
# 1  114800037     493681
# 2  201100448  508775673

# %%
df = ps.pdio.read_files('./municipios.dbf', encoding='utf8')
# Out:
# {'encoding': 'utf8'}

# %%
df.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID          NAME LSAD  \
# 0      72      073  01804517  0500000US72073  72073        Jayuya   13
# 1      72      119  01804540  0500000US72119  72119    Río Grande   13
# 2      72      015  01804487  0500000US72015  72015        Arroyo   13
# 3      72      019  01804489  0500000US72019  72019  Barranquitas   13
# 4      72      071  01804516  0500000US72071  72071       Isabela   13
#
#        ALAND    AWATER                                           geometry
# 0  115340552      3091  <pysal.cg.shapes.Polygon object at 0x7f4e7d643...
# 1  157013546  74871267  <pysal.cg.shapes.Polygon object at 0x7f4e52ee7...
# 2   38869474  53459920  <pysal.cg.shapes.Polygon object at 0x7f4e52ee7...
# 3   88714045     77812  <pysal.cg.shapes.Polygon object at 0x7f4e52ee7...
# 4  143239786  94652927  <pysal.cg.shapes.Polygon object at 0x7f4e52ee7...

# %%
import os

# %%
os.path.abspath(ps.examples.get_path(''))
# Out:
# '/home/ljw/Dropbox/dev/pysal/b898/pysal/examples'

# %%
df.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID          NAME LSAD  \
# 0      72      073  01804517  0500000US72073  72073        Jayuya   13
# 1      72      119  01804540  0500000US72119  72119    Río Grande   13
# 2      72      015  01804487  0500000US72015  72015        Arroyo   13
# 3      72      019  01804489  0500000US72019  72019  Barranquitas   13
# 4      72      071  01804516  0500000US72071  72071       Isabela   13
#
#        ALAND    AWATER                                           geometry
# 0  115340552      3091  <pysal.cg.shapes.Polygon object at 0x7fb8fd8f6...
# 1  157013546  74871267  <pysal.cg.shapes.Polygon object at 0x7fb8fa4fb...
# 2   38869474  53459920  <pysal.cg.shapes.Polygon object at 0x7fb8fa4fb...
# 3   88714045     77812  <pysal.cg.shapes.Polygon object at 0x7fb8fa4fb...
# 4  143239786  94652927  <pysal.cg.shapes.Polygon object at 0x7fb8fa4fb...

# %%
ps.pdio.write_files(df, 'test_df.shp', encoding='utf8')
# Out:
# 72
# 073
# 01804517
# 0500000US72073
# 72073
# Jayuya
# 13
# 72
# 119
# 01804540
# 0500000US72119
# 72119
# Río Grande
# 13
# 72
# 015
# 01804487
# 0500000US72015
# 72015
# Arroyo
# 13
# 72
# 019
# 01804489
# 0500000US72019
# 72019
# Barranquitas
# 13
# 72
# 071
# 01804516
# 0500000US72071
# 72071
# Isabela
# 13
# 72
# 021
# 01804490
# 0500000US72021
# 72021
# Bayamón
# 13
# 72
# 091
# 01804526
# 0500000US72091
# 72091
# Manatí
# 13
# 72
# 025
# 01804492
# 0500000US72025
# 72025
# Caguas
# 13
# 72
# 127
# 01804544
# 0500000US72127
# 72127
# San Juan
# 13
# 72
# 107
# 01804534
# 0500000US72107
# 72107
# Orocovis
# 13
# 72
# 125
# 01804543
# 0500000US72125
# 72125
# San Germán
# 13
# 72
# 003
# 01804481
# 0500000US72003
# 72003
# Aguada
# 13
# 72
# 017
# 01804488
# 0500000US72017
# 72017
# Barceloneta
# 13
# 72
# 045
# 01804502
# 0500000US72045
# 72045
# Comerío
# 13
# 72
# 027
# 01804493
# 0500000US72027
# 72027
# Camuy
# 13
# 72
# 029
# 01804494
# 0500000US72029
# 72029
# Canóvanas
# ...

# %%
ps.pdio.read_files('./test_df.shp', encoding='utf8')
# Out:
# {'encoding': 'utf8'}
#     STATEFP  COUNTYFP  COUNTYNS  AFFGEOID  GEOID  NAME  LSAD  ALAND  AWATER  \
# 0       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 1       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 2       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 3       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 4       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 5       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 6       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 7       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 8       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 9       NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# 10      NaN       NaN       NaN       NaN    NaN   NaN   NaN    NaN     NaN
# ...

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('./test.dbf')

# %%
gdf.NAME[0]
# Out:
# u'R\xc3\xado Grande'
